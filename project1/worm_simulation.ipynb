# %% [markdown]
# # Trying to set out the framework for the worm algorithm
# ### In several places I have put things have 0 added to multiplied by 1 or returning 0. Most of these are just place holders so the code can run.

# %%
import numpy as _np
import matplotlib.pyplot as _plt
import random

# %% [markdown]
# # Set up H and $\beta$ and other fixed variables

# %%
# We set t = 1 for the all simulation parameters so that we can implement the dimensionless Hamiltonian

###################################################### Simulation parameter setting ##########################################################################
N = 2 # Number of total sites in one dimension
mu = 1.4 # Chemical constant
epsilon = 0.03
beta = 12 # beta is defined by 1/ (k * T) where T is the temperature, k is the Boltzmann constant
num_time_steps = int(beta / epsilon)

d = 3 # Number of spacial dimension. Not actually fully flexible, but comes up in formulas

###################################################### Hopping weight setting ##########################################################################
p_move_forward = min(1, _np.exp(mu * epsilon)) # The probability of moving forward in time given it is facing forward, either hop or staying
p_move_forward_hop = epsilon # The probability of hopping given the worm is moving forward (Assuming that we set t = 1 in the problem)
p_move_forward_straight = (1 - 2 * d * p_move_forward_hop) # Straight moving means no spatial hopping (only temporal hopping)
p_move_backward = min(1, _np.exp(-mu * epsilon)) # The probability of moving backwards giving the worm is facing backwards

print('p_move_forward: ' + str(p_move_forward))
print('p_move_forward_hop: ' + str(p_move_forward_hop))
print('p_move_forward_straight: ' + str(p_move_forward_straight))
print('p_move_backward: ' + str(p_move_backward))

weight_no_hop = _np.exp(mu * epsilon) * p_move_forward_straight
weight_hop = _np.exp(mu * epsilon) * p_move_forward_hop

print('weight_no_hop: ' + str(weight_no_hop))
print('weight_hop: ' + str(weight_hop))

class Grid_location(object):
    """
    an object for holding information about what is going on at each grid location
    """
    def __init__(self):
        self.is_particle = False # Whether or not there is a particle on that location.
        self.is_hardcore_boson_violated = False # Whether or not the hardcore boson constraint is violated
        
        """ Where_particle_came_from/is_going there are 2 numbers. The first is whether is moved in x(0)
        y(1) or z(2). The second (-1, 0, +1) is whether the previous/next position was 
        at the current coordinate, or +1 or -1 from it. 
        
        For example a trajector that goes (in Cartesian) (3,4,5) -> (3,5,5) -> (2,5,5) would have where_particle_came_from = [1, -1] and 
        where_particle_is_going = [0, -1] (It looks like we have to be careful with the sign!!)
        
        Note if the particle is stationary where_particle_came_from = [0, 0] or [1, 0] or [2, 0]. It doesn't matter
        """
        self.where_particle_came_from = [0, 0]
        self.where_particle_came_from_hardcore_boson_violated = [0, 0] # Specially used when hardcore boson constraint is violated
        self.where_particle_is_going = [0, 0]
        
        
    def set_where_particle_came_from(self, axis, direction): # axis can be x(0), y(1), z(2) and direction can be -1 and 1
        self.where_particle_came_from = [axis, direction]
    
    def set_where_particle_came_from_hardcore_boson_violated(self, axis, direction): # axis can be x(0), y(1), z(2) and direction can be -1 and 1
        self.where_particle_came_from_hardcore_boson_violated = [axis, direction]
    
    def set_where_particle_is_going(self, axis, direction): # axis can be x(0), y(1), z(2) and direction can be -1 and 1
        self.where_particle_is_going = [axis, direction]
    
    def place_particle(self):
        self.is_particle = True
        
    def remove_particle(self):
        self.is_particle = False
        
def observables(pathed_grid):
    """count up the number of particles and number of hops which gives all information needed to compute
    the weight and energy of the path, then returns the number of particles, the weight of the path and the energy"""
    num_particles = 0 # Running total of number of particles
    num_hops = 0 # Running total of number of steps in which those particles hop
    
    # Loop through the grid
    for x in _np.arange(N):
        for y in _np.arange(N):
            for z in _np.arange(N):
                # For each end location check if there is a path
                time = (num_time_steps - 1) # Start at the end time of the grid and work backwards
                loc = [x, y, z] # Location in space only
                
                if pathed_grid[loc[0], loc[1], loc[2], time].is_particle:
                    num_particles += 1
                
                    # Go through the path
                    while time > 0:
                        step = pathed_grid[loc[0], loc[1], loc[2], time] # The grid_location object where we are in path

                        if step.where_particle_came_from[1] != 0: # If this is 0, there is no hopping
                            num_hops += 1
                                                    
                        # Update location to the previous step on the path
                        loc[step.where_particle_came_from[0]] += step.where_particle_came_from[1]
                        loc[step.where_particle_came_from[0]] %= N #isn't Python great that %= works just like += but for mod 
                        time -= 1
    
    e_tilda = (2 * d * num_particles) - (num_hops / beta)
    weight = (weight_hop ** num_hops) * (weight_no_hop ** ((num_time_steps - 1) * num_particles - num_hops))
    return [num_particles, e_tilda, weight]

"""
grid has indices for time steps, x, y and z. Then at each grid location there is a grid_location object that says whether
there is a particle, where it came from and where it is going.
I think it is good to say where a particle came from each step because the worm algorithm only every  follows a path
backwards.
"""
# Out:
# p_move_forward: 1
# p_move_forward_hop: 0.03
# p_move_forward_straight: 0.8200000000000001
# p_move_backward: 0.9588697805724845
# weight_no_hop: 0.8551734725756259
# weight_hop: 0.03128683436252289
# '\ngrid has indices for time steps, x, y and z. Then at each grid location there is a grid_location object that says whether\nthere is a particle, where it came from and where it is going.\nI think it is good to say where a particle came from each step because the worm algorithm only every  follows a path\nbackwards.\n'

# %% [markdown]
# # Grid visualization

# %%
def plot_grid(pathed_grid, t):
    """This is supposed to plot a 3d grid showing one time step. It should have a green dot at each point where there
    is a particle. There should also be a blue line from each particle to where it came from in the previous time step,
    and a red line leading to where it is going on the next time step. Ideally this would eventually lead to an
    animated version where it shows each time step for ~1s.
    This is currently not working (at least in the edge case where there are not particles, or particles at every point.)
    """
    background_points = []
    particle_points = []
    particle_going_tos = []
    particle_coming_froms = []
    for x in range(N):
        for y in range(N):
            for z in range(N):
                current_location = pathed_grid[x, y, z, t]
                if not current_location.is_particle:
                    background_points.append([x,y,z])
                else:
                    loc = [x,y,z]
                    next_loc = loc.copy()
                    next_loc[current_location.where_particle_is_going[0]] += current_location.where_particle_is_going[1]
                    next_loc[current_location.where_particle_is_going[0]] %= N
                    previous_loc = loc.copy()
                    previous_loc[current_location.where_particle_came_from[0]] += current_location.where_particle_came_from[1]
                    previous_loc[current_location.where_particle_came_from[0]] %= N
                    particle_points.append(loc)
                    particle_going_tos.append(next_loc)
                    particle_coming_froms.append(previous_loc)
                    
                
    ax = _plt.axes(projection='3d')
    
    bp =_np.array(background_points).T
    print(background_points, bp)
    print(particle_points)
    
    ax.scatter(bp[0], bp[1], bp[2], color="grey", marker=".", alpha="0.5")
    ax.scatter(*_np.array(particle_points).T)
    for i in range(length(particle_points)):
        ax.plot(*_np.array([particle_going_tos[i], particle_points[i]]).T, color="red")
        ax.plot(*_np.array([particle_coming_froms[i], particle_points[i]]).T, color="blue")

# %%
plot_grid(grid, 0)

# %%
ax = _plt.axes(projection='3d')
ax.scatter3D(*_np.array([[0,0,1], [0,1,0], [1,0,0]]))

# %% [markdown]
# ## This part is the actual worm algorithm

# %%
def unit_move_forward(loc, hop_axis, hop_direction, N, num_time_steps): # Temporal forward
    new_loc = loc.copy()
    new_loc[hop_axis] = (loc[hop_axis] + hop_direction) % N # Periodic condition
    new_loc[3] = (loc[3] + 1) % num_time_steps
    
    return new_loc

def unit_move_backward(loc, hop_axis, hop_direction, N, num_time_steps): # Temporal backward
    new_loc = loc.copy()
    new_loc[hop_axis] = (loc[hop_axis] + hop_direction) % N # Periodic condition
    new_loc[3] = (loc[3] - 1) % num_time_steps
    
    return new_loc
    
def move_forward(loc, pathed_grid):
    """
    This function updates the grid if the worm moves forward. It needs to do 3 things:
    1) choose a next location to go to
    2) update where_particle_is_going on the old location and where_particle_came_from on the new location
    3) deal with complications if there is already a particle at the location"""
    
    facing_forward = True # Defines the final temporal direction after finishing the function
    
    #### Store the old & new location information first ####
    old_grid_location = pathed_grid[tuple(loc)]  
    new_loc = loc.copy() # Initialization
      
    #### Hopping ####
    if random.uniform(0, 1) < p_move_forward_straight:
        # Don't hop spatially, just move forward in time
        hop_axis = 0
        hop_direction = 0
        new_loc = unit_move_forward(loc, hop_axis, hop_direction, N, num_time_steps)
        
    else:        
        # Hop both temporal and spatial at this time step
        hop_axis = random.randint(0, d - 1) # Get an integer 0 ~ 2 inclusive for the axis to move on (0: x, 1: y, 2: z)
        hop_direction = 2 * random.getrandbits(1) - 1 # For the direction, get +1 = 2 * 1 - 1 or -1 = 2 * 0 - 1
        
        new_loc = unit_move_forward(loc, hop_axis, hop_direction, N, num_time_steps)
        
        # Update the old location to say where it is going
        old_grid_location.set_where_particle_is_going(hop_axis, hop_direction)    
    
    #### Check the hardcore boson constraint ####
    new_grid_location = pathed_grid[tuple(new_loc)]
    
    if new_grid_location.is_particle:
        # Now in the condition of at a spot with two particles and the arrow facing (hardcore boson constraint is violated)
        facing_forward = False # Now we have to move backward 
        new_grid_location.is_hardcore_boson_violated = True
        
        # Save the information of original path
        original_axis = new_grid_location.where_particle_came_from[0]
        original_direction = new_grid_location.where_particle_came_from[1]
        
        new_grid_location.set_where_particle_came_from_hardcore_boson_violated(original_axis, original_direction)
        new_grid_location.set_where_particle_came_from(hop_axis, -hop_direction)
        
    else: 
        # If there is no particle at the new location, just update it
        new_grid_location.set_where_particle_came_from(hop_axis, -hop_direction)
        new_grid_location.place_particle()
        
    return new_loc, facing_forward
        
            
def update_grid(pathed_grid):
    """
    worm update algorithm goes here
    """
    # Pick initial site
    x0, y0, z0 = random.randrange(N), random.randrange(N), random.randrange(N)
    t0 = random.randrange(num_time_steps)
    loc0 = [x0, y0, z0, t0] # Original location
    
    # Initial up arrow if there is no particle
    facing_forward = not(pathed_grid[tuple(loc0)].is_particle)
    
    # Current location of the worm
    tail = loc0.copy()
    head = loc0.copy() # When copying the array, be careful with shallow & deep copy !!
    keep_going = True
    
    counter = 0
    while keep_going:        
        #print("hi", loc, facing_forward)
        if facing_forward:
            if random.uniform(0, 1) <= p_move_forward: # Move forward proposal accepted
                head, facing_forward = move_forward(head, pathed_grid)
            else:
                facing_forward = False
                
        else:
        #     For the case of the worm facing backwards     
        #     For facing backwards the steps are as follows
        #     1) go back one along the path, deleting the particle at the current location
        #     2) switch the arrow to something like facing forward, except the probabilities of adding a new step
        #       are different
            
            current_grid_location = pathed_grid[tuple(head)]
            
            # Hopping axis and direction setting (be careful with the hardcore boson violation condition)       
            if current_grid_location.is_hardcore_boson_violated == True:
                hop_back_axis = current_grid_location.where_particle_came_from_hardcore_boson_violated[0]
                hop_back_direction = current_grid_location.where_particle_came_from_hardcore_boson_violated[1]  

            else:
                hop_back_axis = current_grid_location.where_particle_came_from[0]
                hop_back_direction = current_grid_location.where_particle_came_from[1]     
            
            # Particle removal (be careful with the hardcore boson violation condition)
            if counter!=0 and current_grid_location.is_hardcore_boson_violated == False: current_grid_location.remove_particle() # If it is the initial backward try, we should not remove the particle
            
            # Edge removal (be careful with the hardcore boson violation condition)
            if current_grid_location.is_hardcore_boson_violated == True:
                current_grid_location.set_where_particle_came_from_hardcore_boson_violated(0, 0) # Remove the spatial hopping edge
            else:
                current_grid_location.set_where_particle_came_from(0, 0) 
            
            current_grid_location.is_hardcore_boson_violated = False          
            
            if random.uniform(0, 1) <= p_move_backward: # Move back proposal accepted
                head = unit_move_backward(head, hop_back_axis, hop_back_direction, N, num_time_steps)
                new_grid_location = pathed_grid[tuple(head)]
                new_grid_location.set_where_particle_is_going(0, 0) # Remove the spatial hopping edge
                
            else:
                head = unit_move_backward(head, hop_back_axis, hop_back_direction, N, num_time_steps)
                new_grid_location = pathed_grid[tuple(head)]
                new_grid_location.set_where_particle_is_going(0, 0) # Remove the spatial hopping edge
                
                head, facing_forward = move_forward(head, pathed_grid)
                
        # Now check whether we have arrive back at the place we started
        # I don't think it is possible to arrive back at the start without having finished the worm - I also agree (Jiyong)
        keep_going = (head != tail)
        counter += 1

    # Finally removing the particle at the tail
    pathed_grid[tuple(tail)].remove_particle()
    
    return pathed_grid

# %% [markdown]
# # This next box is where the simulation acutally happens

# %%
################# Make the block ###################
def block(array, N):
    # Device the given array into blocks with length N
    
    l = int(len(array) / N)
    
    blocked_array = _np.zeros([l, N])
    
    for i in range(0, l):
        block_start = i * N
        block_end = block_start + N
        
        blocked_array[i] = array[block_start: block_end]
        
    return blocked_array

################# Calculate the whole average of blocks ###################
def total_block_average(blocked_array_observable):
    # Device the given array into blocks with length N
    
    l = len(blocked_array_observable)
    each_block_average_array = _np.zeros(l)
    
    for i in range(l):
        each_block_average = _np.average(blocked_array_observable[i])
        each_block_average_array[i] = each_block_average

    return _np.average(each_block_average_array)


# 4-dimensional array so that we can store the information of both space and time
grid = _np.full((N, N, N, num_time_steps), Grid_location()) # Initialization

# If we use the above definition, all objects refer to the same memory address.
# In this case, if we change one grid location, all grid locations are changed simultaneously
# Therefore, we have to initialize the grid as below
for x in range(N):
    for y in range(N):
        for z in range(N):
            for t in range(num_time_steps):
                grid[x, y, z, t] = Grid_location()

num_trials = 100000 # I think in one of the lectures, prof said we should expect this ot take ~1 million trials
ns = [] # Number of particles in each trial
es = [] # Energy of path in each trial
Ws = [] # Weight of paths in each trial

for counter in range(num_trials):
    num_particles, e_tilda, weight = observables(grid)
    Ws.append(weight)
    ns.append(num_particles)
    es.append(e_tilda)
    grid = update_grid(grid)
    
    print('-----------------' + str(counter) + ' New grid created----------------------')
    
Monte_Carlo_try = range(num_trials)
_plt.rcParams['figure.facecolor'] = 'white'
_plt.plot(Monte_Carlo_try, ns, 'r')
_plt.xlabel('Monte Carlo try', fontsize = 12)
_plt.ylabel('Number of particle', fontsize = 12)

_plt.figure()
_plt.plot(Monte_Carlo_try, es, 'b')
_plt.xlabel('Monte Carlo try', fontsize = 12)
_plt.ylabel('Energy of path', fontsize = 12)

block_size = 2500

ns = ns[2500:]
es = es[2500:]

ns_block = block(ns, block_size)
es_block = block(es, block_size)

print(total_block_average(ns_block))
print(total_block_average(es_block))
# Out:
# -----------------0 New grid created----------------------
# -----------------1 New grid created----------------------
# -----------------2 New grid created----------------------
# -----------------3 New grid created----------------------
# -----------------4 New grid created----------------------
# -----------------5 New grid created----------------------
# -----------------6 New grid created----------------------
# -----------------7 New grid created----------------------
# -----------------8 New grid created----------------------
# -----------------9 New grid created----------------------
# -----------------10 New grid created----------------------
# -----------------11 New grid created----------------------
# -----------------12 New grid created----------------------
# -----------------13 New grid created----------------------
# -----------------14 New grid created----------------------
# -----------------15 New grid created----------------------
# -----------------16 New grid created----------------------
# -----------------17 New grid created----------------------
# -----------------18 New grid created----------------------
# -----------------19 New grid created----------------------
# -----------------20 New grid created----------------------
# -----------------21 New grid created----------------------
# -----------------22 New grid created----------------------
# -----------------23 New grid created----------------------
# -----------------24 New grid created----------------------
# -----------------25 New grid created----------------------
# -----------------26 New grid created----------------------
# -----------------27 New grid created----------------------
# -----------------28 New grid created----------------------
# -----------------29 New grid created----------------------
# -----------------30 New grid created----------------------
# -----------------31 New grid created----------------------
# -----------------32 New grid created----------------------
# -----------------33 New grid created----------------------
# -----------------34 New grid created----------------------
# -----------------35 New grid created----------------------
# -----------------36 New grid created----------------------
# -----------------37 New grid created----------------------
# -----------------38 New grid created----------------------
# -----------------39 New grid created----------------------
# -----------------40 New grid created----------------------
# -----------------41 New grid created----------------------
# -----------------42 New grid created----------------------
# -----------------43 New grid created----------------------
# -----------------44 New grid created----------------------
# -----------------45 New grid created----------------------
# -----------------46 New grid created----------------------
# -----------------47 New grid created----------------------
# -----------------48 New grid created----------------------
# -----------------49 New grid created----------------------
# -----------------50 New grid created----------------------
# -----------------51 New grid created----------------------
# -----------------52 New grid created----------------------
# -----------------53 New grid created----------------------
# -----------------54 New grid created----------------------
# -----------------55 New grid created----------------------
# -----------------56 New grid created----------------------
# -----------------57 New grid created----------------------
# -----------------58 New grid created----------------------
# -----------------59 New grid created----------------------
# -----------------60 New grid created----------------------
# -----------------61 New grid created----------------------
# -----------------62 New grid created----------------------
# -----------------63 New grid created----------------------
# -----------------64 New grid created----------------------
# -----------------65 New grid created----------------------
# -----------------66 New grid created----------------------
# -----------------67 New grid created----------------------
# -----------------68 New grid created----------------------
# -----------------69 New grid created----------------------
# -----------------70 New grid created----------------------
# -----------------71 New grid created----------------------
# -----------------72 New grid created----------------------
# -----------------73 New grid created----------------------
# -----------------74 New grid created----------------------
# -----------------75 New grid created----------------------
# -----------------76 New grid created----------------------
# -----------------77 New grid created----------------------
# -----------------78 New grid created----------------------
# -----------------79 New grid created----------------------
# -----------------80 New grid created----------------------
# -----------------81 New grid created----------------------
# -----------------82 New grid created----------------------
# -----------------83 New grid created----------------------
# -----------------84 New grid created----------------------
# -----------------85 New grid created----------------------
# -----------------86 New grid created----------------------
# -----------------87 New grid created----------------------
# -----------------88 New grid created----------------------
# -----------------89 New grid created----------------------
# -----------------90 New grid created----------------------
# -----------------91 New grid created----------------------
# -----------------92 New grid created----------------------
# -----------------93 New grid created----------------------
# -----------------94 New grid created----------------------
# -----------------95 New grid created----------------------
# -----------------96 New grid created----------------------
# -----------------97 New grid created----------------------
# -----------------98 New grid created----------------------
# -----------------99 New grid created----------------------
# -----------------100 New grid created----------------------
# -----------------101 New grid created----------------------
# -----------------102 New grid created----------------------
# -----------------103 New grid created----------------------
# -----------------104 New grid created----------------------
# -----------------105 New grid created----------------------
# -----------------106 New grid created----------------------
# -----------------107 New grid created----------------------
# -----------------108 New grid created----------------------
# -----------------109 New grid created----------------------
# -----------------110 New grid created----------------------
# -----------------111 New grid created----------------------
# -----------------112 New grid created----------------------
# -----------------113 New grid created----------------------
# -----------------114 New grid created----------------------
# -----------------115 New grid created----------------------
# -----------------116 New grid created----------------------
# -----------------117 New grid created----------------------
# -----------------118 New grid created----------------------
# -----------------119 New grid created----------------------
# -----------------120 New grid created----------------------
# -----------------121 New grid created----------------------
# -----------------122 New grid created----------------------
# -----------------123 New grid created----------------------
# -----------------124 New grid created----------------------
# -----------------125 New grid created----------------------
# -----------------126 New grid created----------------------
# -----------------127 New grid created----------------------
# -----------------128 New grid created----------------------
# -----------------129 New grid created----------------------
# -----------------130 New grid created----------------------
# -----------------131 New grid created----------------------
# -----------------132 New grid created----------------------
# -----------------133 New grid created----------------------
# -----------------134 New grid created----------------------
# -----------------135 New grid created----------------------
# -----------------136 New grid created----------------------
# -----------------137 New grid created----------------------
# -----------------138 New grid created----------------------
# -----------------139 New grid created----------------------
# -----------------140 New grid created----------------------
# -----------------141 New grid created----------------------
# -----------------142 New grid created----------------------
# -----------------143 New grid created----------------------
# -----------------144 New grid created----------------------
# -----------------145 New grid created----------------------
# -----------------146 New grid created----------------------
# -----------------147 New grid created----------------------
# -----------------148 New grid created----------------------
# -----------------149 New grid created----------------------
# -----------------150 New grid created----------------------
# -----------------151 New grid created----------------------
# -----------------152 New grid created----------------------
# -----------------153 New grid created----------------------
# -----------------154 New grid created----------------------
# -----------------155 New grid created----------------------
# -----------------156 New grid created----------------------
# -----------------157 New grid created----------------------
# -----------------158 New grid created----------------------
# -----------------159 New grid created----------------------
# -----------------160 New grid created----------------------
# -----------------161 New grid created----------------------
# -----------------162 New grid created----------------------
# -----------------163 New grid created----------------------
# -----------------164 New grid created----------------------
# -----------------165 New grid created----------------------
# -----------------166 New grid created----------------------
# -----------------167 New grid created----------------------
# -----------------168 New grid created----------------------
# -----------------169 New grid created----------------------
# -----------------170 New grid created----------------------
# -----------------171 New grid created----------------------
# -----------------172 New grid created----------------------
# -----------------173 New grid created----------------------
# -----------------174 New grid created----------------------
# -----------------175 New grid created----------------------
# -----------------176 New grid created----------------------
# -----------------177 New grid created----------------------
# -----------------178 New grid created----------------------
# -----------------179 New grid created----------------------
# -----------------180 New grid created----------------------
# -----------------181 New grid created----------------------
# -----------------182 New grid created----------------------
# -----------------183 New grid created----------------------
# -----------------184 New grid created----------------------
# -----------------185 New grid created----------------------
# -----------------186 New grid created----------------------
# -----------------187 New grid created----------------------
# -----------------188 New grid created----------------------
# -----------------189 New grid created----------------------
# -----------------190 New grid created----------------------
# -----------------191 New grid created----------------------
# -----------------192 New grid created----------------------
# -----------------193 New grid created----------------------
# -----------------194 New grid created----------------------
# -----------------195 New grid created----------------------
# -----------------196 New grid created----------------------
# -----------------197 New grid created----------------------
# -----------------198 New grid created----------------------
# -----------------199 New grid created----------------------
# -----------------200 New grid created----------------------
# -----------------201 New grid created----------------------
# -----------------202 New grid created----------------------
# -----------------203 New grid created----------------------
# -----------------204 New grid created----------------------
# -----------------205 New grid created----------------------
# -----------------206 New grid created----------------------
# -----------------207 New grid created----------------------
# -----------------208 New grid created----------------------
# -----------------209 New grid created----------------------
# -----------------210 New grid created----------------------
# -----------------211 New grid created----------------------
# -----------------212 New grid created----------------------
# -----------------213 New grid created----------------------
# -----------------214 New grid created----------------------
# -----------------215 New grid created----------------------
# -----------------216 New grid created----------------------
# -----------------217 New grid created----------------------
# -----------------218 New grid created----------------------
# -----------------219 New grid created----------------------
# -----------------220 New grid created----------------------
# -----------------221 New grid created----------------------
# -----------------222 New grid created----------------------
# -----------------223 New grid created----------------------
# -----------------224 New grid created----------------------
# -----------------225 New grid created----------------------
# -----------------226 New grid created----------------------
# -----------------227 New grid created----------------------
# -----------------228 New grid created----------------------
# -----------------229 New grid created----------------------
# -----------------230 New grid created----------------------
# -----------------231 New grid created----------------------
# -----------------232 New grid created----------------------
# -----------------233 New grid created----------------------
# -----------------234 New grid created----------------------
# -----------------235 New grid created----------------------
# -----------------236 New grid created----------------------
# -----------------237 New grid created----------------------
# -----------------238 New grid created----------------------
# -----------------239 New grid created----------------------
# -----------------240 New grid created----------------------
# -----------------241 New grid created----------------------
# -----------------242 New grid created----------------------
# -----------------243 New grid created----------------------
# -----------------244 New grid created----------------------
# -----------------245 New grid created----------------------
# -----------------246 New grid created----------------------
# -----------------247 New grid created----------------------
# -----------------248 New grid created----------------------
# -----------------249 New grid created----------------------
# -----------------250 New grid created----------------------
# -----------------251 New grid created----------------------
# -----------------252 New grid created----------------------
# -----------------253 New grid created----------------------
# -----------------254 New grid created----------------------
# -----------------255 New grid created----------------------
# -----------------256 New grid created----------------------
# -----------------257 New grid created----------------------
# -----------------258 New grid created----------------------
# -----------------259 New grid created----------------------
# -----------------260 New grid created----------------------
# -----------------261 New grid created----------------------
# -----------------262 New grid created----------------------
# -----------------263 New grid created----------------------
# -----------------264 New grid created----------------------
# -----------------265 New grid created----------------------
# -----------------266 New grid created----------------------
# -----------------267 New grid created----------------------
# -----------------268 New grid created----------------------
# -----------------269 New grid created----------------------
# -----------------270 New grid created----------------------
# -----------------271 New grid created----------------------
# -----------------272 New grid created----------------------
# -----------------273 New grid created----------------------
# -----------------274 New grid created----------------------
# -----------------275 New grid created----------------------
# -----------------276 New grid created----------------------
# -----------------277 New grid created----------------------
# -----------------278 New grid created----------------------
# -----------------279 New grid created----------------------
# -----------------280 New grid created----------------------
# -----------------281 New grid created----------------------
# -----------------282 New grid created----------------------
# -----------------283 New grid created----------------------
# -----------------284 New grid created----------------------
# -----------------285 New grid created----------------------
# -----------------286 New grid created----------------------
# -----------------287 New grid created----------------------
# -----------------288 New grid created----------------------
# -----------------289 New grid created----------------------
# -----------------290 New grid created----------------------
# -----------------291 New grid created----------------------
# -----------------292 New grid created----------------------
# -----------------293 New grid created----------------------
# -----------------294 New grid created----------------------
# -----------------295 New grid created----------------------
# -----------------296 New grid created----------------------
# -----------------297 New grid created----------------------
# -----------------298 New grid created----------------------
# -----------------299 New grid created----------------------
# -----------------300 New grid created----------------------
# -----------------301 New grid created----------------------
# -----------------302 New grid created----------------------
# -----------------303 New grid created----------------------
# -----------------304 New grid created----------------------
# -----------------305 New grid created----------------------
# -----------------306 New grid created----------------------
# -----------------307 New grid created----------------------
# -----------------308 New grid created----------------------
# -----------------309 New grid created----------------------
# -----------------310 New grid created----------------------
# -----------------311 New grid created----------------------
# -----------------312 New grid created----------------------
# -----------------313 New grid created----------------------
# -----------------314 New grid created----------------------
# -----------------315 New grid created----------------------
# -----------------316 New grid created----------------------
# -----------------317 New grid created----------------------
# -----------------318 New grid created----------------------
# -----------------319 New grid created----------------------
# -----------------320 New grid created----------------------
# -----------------321 New grid created----------------------
# -----------------322 New grid created----------------------
# -----------------323 New grid created----------------------
# -----------------324 New grid created----------------------
# -----------------325 New grid created----------------------
# -----------------326 New grid created----------------------
# -----------------327 New grid created----------------------
# -----------------328 New grid created----------------------
# -----------------329 New grid created----------------------
# -----------------330 New grid created----------------------
# -----------------331 New grid created----------------------
# -----------------332 New grid created----------------------
# -----------------333 New grid created----------------------
# -----------------334 New grid created----------------------
# -----------------335 New grid created----------------------
# -----------------336 New grid created----------------------
# -----------------337 New grid created----------------------
# -----------------338 New grid created----------------------
# -----------------339 New grid created----------------------
# -----------------340 New grid created----------------------
# -----------------341 New grid created----------------------
# -----------------342 New grid created----------------------
# -----------------343 New grid created----------------------
# -----------------344 New grid created----------------------
# -----------------345 New grid created----------------------
# -----------------346 New grid created----------------------
# -----------------347 New grid created----------------------
# -----------------348 New grid created----------------------
# -----------------349 New grid created----------------------
# -----------------350 New grid created----------------------
# -----------------351 New grid created----------------------
# -----------------352 New grid created----------------------
# -----------------353 New grid created----------------------
# -----------------354 New grid created----------------------
# -----------------355 New grid created----------------------
# -----------------356 New grid created----------------------
# -----------------357 New grid created----------------------
# -----------------358 New grid created----------------------
# -----------------359 New grid created----------------------
# -----------------360 New grid created----------------------
# -----------------361 New grid created----------------------
# -----------------362 New grid created----------------------
# -----------------363 New grid created----------------------
# -----------------364 New grid created----------------------
# -----------------365 New grid created----------------------
# -----------------366 New grid created----------------------
# -----------------367 New grid created----------------------
# -----------------368 New grid created----------------------
# -----------------369 New grid created----------------------
# -----------------370 New grid created----------------------
# -----------------371 New grid created----------------------
# -----------------372 New grid created----------------------
# -----------------373 New grid created----------------------
# -----------------374 New grid created----------------------
# -----------------375 New grid created----------------------
# -----------------376 New grid created----------------------
# -----------------377 New grid created----------------------
# -----------------378 New grid created----------------------
# -----------------379 New grid created----------------------
# -----------------380 New grid created----------------------
# -----------------381 New grid created----------------------
# -----------------382 New grid created----------------------
# -----------------383 New grid created----------------------
# -----------------384 New grid created----------------------
# -----------------385 New grid created----------------------
# -----------------386 New grid created----------------------
# -----------------387 New grid created----------------------
# -----------------388 New grid created----------------------
# -----------------389 New grid created----------------------
# -----------------390 New grid created----------------------
# -----------------391 New grid created----------------------
# -----------------392 New grid created----------------------
# -----------------393 New grid created----------------------
# -----------------394 New grid created----------------------
# -----------------395 New grid created----------------------
# -----------------396 New grid created----------------------
# -----------------397 New grid created----------------------
# -----------------398 New grid created----------------------
# -----------------399 New grid created----------------------
# -----------------400 New grid created----------------------
# -----------------401 New grid created----------------------
# -----------------402 New grid created----------------------
# -----------------403 New grid created----------------------
# -----------------404 New grid created----------------------
# -----------------405 New grid created----------------------
# -----------------406 New grid created----------------------
# -----------------407 New grid created----------------------
# -----------------408 New grid created----------------------
# -----------------409 New grid created----------------------
# -----------------410 New grid created----------------------
# -----------------411 New grid created----------------------
# -----------------412 New grid created----------------------
# -----------------413 New grid created----------------------
# -----------------414 New grid created----------------------
# -----------------415 New grid created----------------------
# -----------------416 New grid created----------------------
# -----------------417 New grid created----------------------
# -----------------418 New grid created----------------------
# -----------------419 New grid created----------------------
# -----------------420 New grid created----------------------
# -----------------421 New grid created----------------------
# -----------------422 New grid created----------------------
# -----------------423 New grid created----------------------
# -----------------424 New grid created----------------------
# -----------------425 New grid created----------------------
# -----------------426 New grid created----------------------
# -----------------427 New grid created----------------------
# -----------------428 New grid created----------------------
# -----------------429 New grid created----------------------
# -----------------430 New grid created----------------------
# -----------------431 New grid created----------------------
# -----------------432 New grid created----------------------
# -----------------433 New grid created----------------------
# -----------------434 New grid created----------------------
# -----------------435 New grid created----------------------
# -----------------436 New grid created----------------------
# -----------------437 New grid created----------------------
# -----------------438 New grid created----------------------
# -----------------439 New grid created----------------------
# -----------------440 New grid created----------------------
# -----------------441 New grid created----------------------
# -----------------442 New grid created----------------------
# -----------------443 New grid created----------------------
# -----------------444 New grid created----------------------
# -----------------445 New grid created----------------------
# -----------------446 New grid created----------------------
# -----------------447 New grid created----------------------
# -----------------448 New grid created----------------------
# -----------------449 New grid created----------------------
# -----------------450 New grid created----------------------
# -----------------451 New grid created----------------------
# -----------------452 New grid created----------------------
# -----------------453 New grid created----------------------
# -----------------454 New grid created----------------------
# -----------------455 New grid created----------------------
# -----------------456 New grid created----------------------
# -----------------457 New grid created----------------------
# -----------------458 New grid created----------------------
# -----------------459 New grid created----------------------
# -----------------460 New grid created----------------------
# -----------------461 New grid created----------------------
# -----------------462 New grid created----------------------
# -----------------463 New grid created----------------------
# -----------------464 New grid created----------------------
# -----------------465 New grid created----------------------
# -----------------466 New grid created----------------------
# -----------------467 New grid created----------------------
# -----------------468 New grid created----------------------
# -----------------469 New grid created----------------------
# -----------------470 New grid created----------------------
# -----------------471 New grid created----------------------
# -----------------472 New grid created----------------------
# -----------------473 New grid created----------------------
# -----------------474 New grid created----------------------
# -----------------475 New grid created----------------------
# -----------------476 New grid created----------------------
# -----------------477 New grid created----------------------
# -----------------478 New grid created----------------------
# -----------------479 New grid created----------------------
# -----------------480 New grid created----------------------
# -----------------481 New grid created----------------------
# -----------------482 New grid created----------------------
# -----------------483 New grid created----------------------
# -----------------484 New grid created----------------------
# -----------------485 New grid created----------------------
# -----------------486 New grid created----------------------
# -----------------487 New grid created----------------------
# -----------------488 New grid created----------------------
# -----------------489 New grid created----------------------
# -----------------490 New grid created----------------------
# -----------------491 New grid created----------------------
# -----------------492 New grid created----------------------
# -----------------493 New grid created----------------------
# -----------------494 New grid created----------------------
# -----------------495 New grid created----------------------
# -----------------496 New grid created----------------------
# -----------------497 New grid created----------------------
# -----------------498 New grid created----------------------
# -----------------499 New grid created----------------------
# -----------------500 New grid created----------------------
# -----------------501 New grid created----------------------
# -----------------502 New grid created----------------------
# -----------------503 New grid created----------------------
# -----------------504 New grid created----------------------
# -----------------505 New grid created----------------------
# -----------------506 New grid created----------------------
# -----------------507 New grid created----------------------
# -----------------508 New grid created----------------------
# -----------------509 New grid created----------------------
# -----------------510 New grid created----------------------
# -----------------511 New grid created----------------------
# -----------------512 New grid created----------------------
# -----------------513 New grid created----------------------
# -----------------514 New grid created----------------------
# -----------------515 New grid created----------------------
# -----------------516 New grid created----------------------
# -----------------517 New grid created----------------------
# -----------------518 New grid created----------------------
# -----------------519 New grid created----------------------
# -----------------520 New grid created----------------------
# -----------------521 New grid created----------------------
# -----------------522 New grid created----------------------
# -----------------523 New grid created----------------------
# -----------------524 New grid created----------------------
# -----------------525 New grid created----------------------
# -----------------526 New grid created----------------------
# -----------------527 New grid created----------------------
# -----------------528 New grid created----------------------
# -----------------529 New grid created----------------------
# -----------------530 New grid created----------------------
# -----------------531 New grid created----------------------
# -----------------532 New grid created----------------------
# -----------------533 New grid created----------------------
# -----------------534 New grid created----------------------
# -----------------535 New grid created----------------------
# -----------------536 New grid created----------------------
# -----------------537 New grid created----------------------
# -----------------538 New grid created----------------------
# -----------------539 New grid created----------------------
# -----------------540 New grid created----------------------
# -----------------541 New grid created----------------------
# -----------------542 New grid created----------------------
# -----------------543 New grid created----------------------
# -----------------544 New grid created----------------------
# -----------------545 New grid created----------------------
# -----------------546 New grid created----------------------
# -----------------547 New grid created----------------------
# -----------------548 New grid created----------------------
# -----------------549 New grid created----------------------
# -----------------550 New grid created----------------------
# -----------------551 New grid created----------------------
# -----------------552 New grid created----------------------
# -----------------553 New grid created----------------------
# -----------------554 New grid created----------------------
# -----------------555 New grid created----------------------
# -----------------556 New grid created----------------------
# -----------------557 New grid created----------------------
# -----------------558 New grid created----------------------
# -----------------559 New grid created----------------------
# -----------------560 New grid created----------------------
# -----------------561 New grid created----------------------
# -----------------562 New grid created----------------------
# -----------------563 New grid created----------------------
# -----------------564 New grid created----------------------
# -----------------565 New grid created----------------------
# -----------------566 New grid created----------------------
# -----------------567 New grid created----------------------
# -----------------568 New grid created----------------------
# -----------------569 New grid created----------------------
# -----------------570 New grid created----------------------
# -----------------571 New grid created----------------------
# -----------------572 New grid created----------------------
# -----------------573 New grid created----------------------
# -----------------574 New grid created----------------------
# -----------------575 New grid created----------------------
# -----------------576 New grid created----------------------
# -----------------577 New grid created----------------------
# -----------------578 New grid created----------------------
# -----------------579 New grid created----------------------
# -----------------580 New grid created----------------------
# -----------------581 New grid created----------------------
# -----------------582 New grid created----------------------
# -----------------583 New grid created----------------------
# -----------------584 New grid created----------------------
# -----------------585 New grid created----------------------
# -----------------586 New grid created----------------------
# -----------------587 New grid created----------------------
# -----------------588 New grid created----------------------
# -----------------589 New grid created----------------------
# -----------------590 New grid created----------------------
# -----------------591 New grid created----------------------
# -----------------592 New grid created----------------------
# -----------------593 New grid created----------------------
# -----------------594 New grid created----------------------
# -----------------595 New grid created----------------------
# -----------------596 New grid created----------------------
# -----------------597 New grid created----------------------
# -----------------598 New grid created----------------------
# -----------------599 New grid created----------------------
# -----------------600 New grid created----------------------
# -----------------601 New grid created----------------------
# -----------------602 New grid created----------------------
# -----------------603 New grid created----------------------
# -----------------604 New grid created----------------------
# -----------------605 New grid created----------------------
# -----------------606 New grid created----------------------
# -----------------607 New grid created----------------------
# -----------------608 New grid created----------------------
# -----------------609 New grid created----------------------
# -----------------610 New grid created----------------------
# -----------------611 New grid created----------------------
# -----------------612 New grid created----------------------
# -----------------613 New grid created----------------------
# -----------------614 New grid created----------------------
# -----------------615 New grid created----------------------
# -----------------616 New grid created----------------------
# -----------------617 New grid created----------------------
# -----------------618 New grid created----------------------
# -----------------619 New grid created----------------------
# -----------------620 New grid created----------------------
# -----------------621 New grid created----------------------
# -----------------622 New grid created----------------------
# -----------------623 New grid created----------------------
# -----------------624 New grid created----------------------
# -----------------625 New grid created----------------------
# -----------------626 New grid created----------------------
# -----------------627 New grid created----------------------
# -----------------628 New grid created----------------------
# -----------------629 New grid created----------------------
# -----------------630 New grid created----------------------
# -----------------631 New grid created----------------------
# -----------------632 New grid created----------------------
# -----------------633 New grid created----------------------
# -----------------634 New grid created----------------------
# -----------------635 New grid created----------------------
# -----------------636 New grid created----------------------
# -----------------637 New grid created----------------------
# -----------------638 New grid created----------------------
# -----------------639 New grid created----------------------
# -----------------640 New grid created----------------------
# -----------------641 New grid created----------------------
# -----------------642 New grid created----------------------
# -----------------643 New grid created----------------------
# -----------------644 New grid created----------------------
# -----------------645 New grid created----------------------
# -----------------646 New grid created----------------------
# -----------------647 New grid created----------------------
# -----------------648 New grid created----------------------
# -----------------649 New grid created----------------------
# -----------------650 New grid created----------------------
# -----------------651 New grid created----------------------
# -----------------652 New grid created----------------------
# -----------------653 New grid created----------------------
# -----------------654 New grid created----------------------
# -----------------655 New grid created----------------------
# -----------------656 New grid created----------------------
# -----------------657 New grid created----------------------
# -----------------658 New grid created----------------------
# -----------------659 New grid created----------------------
# -----------------660 New grid created----------------------
# -----------------661 New grid created----------------------
# -----------------662 New grid created----------------------
# -----------------663 New grid created----------------------
# -----------------664 New grid created----------------------
# -----------------665 New grid created----------------------
# -----------------666 New grid created----------------------
# -----------------667 New grid created----------------------
# -----------------668 New grid created----------------------
# -----------------669 New grid created----------------------
# -----------------670 New grid created----------------------
# -----------------671 New grid created----------------------
# -----------------672 New grid created----------------------
# -----------------673 New grid created----------------------
# -----------------674 New grid created----------------------
# -----------------675 New grid created----------------------
# -----------------676 New grid created----------------------
# -----------------677 New grid created----------------------
# -----------------678 New grid created----------------------
# -----------------679 New grid created----------------------
# -----------------680 New grid created----------------------
# -----------------681 New grid created----------------------
# -----------------682 New grid created----------------------
# -----------------683 New grid created----------------------
# -----------------684 New grid created----------------------
# -----------------685 New grid created----------------------
# -----------------686 New grid created----------------------
# -----------------687 New grid created----------------------
# -----------------688 New grid created----------------------
# -----------------689 New grid created----------------------
# -----------------690 New grid created----------------------
# -----------------691 New grid created----------------------
# -----------------692 New grid created----------------------
# -----------------693 New grid created----------------------
# -----------------694 New grid created----------------------
# -----------------695 New grid created----------------------
# -----------------696 New grid created----------------------
# -----------------697 New grid created----------------------
# -----------------698 New grid created----------------------
# -----------------699 New grid created----------------------
# -----------------700 New grid created----------------------
# -----------------701 New grid created----------------------
# -----------------702 New grid created----------------------
# -----------------703 New grid created----------------------
# -----------------704 New grid created----------------------
# -----------------705 New grid created----------------------
# -----------------706 New grid created----------------------
# -----------------707 New grid created----------------------
# -----------------708 New grid created----------------------
# -----------------709 New grid created----------------------
# -----------------710 New grid created----------------------
# -----------------711 New grid created----------------------
# -----------------712 New grid created----------------------
# -----------------713 New grid created----------------------
# -----------------714 New grid created----------------------
# -----------------715 New grid created----------------------
# -----------------716 New grid created----------------------
# -----------------717 New grid created----------------------
# -----------------718 New grid created----------------------
# -----------------719 New grid created----------------------
# -----------------720 New grid created----------------------
# -----------------721 New grid created----------------------
# -----------------722 New grid created----------------------
# -----------------723 New grid created----------------------
# -----------------724 New grid created----------------------
# -----------------725 New grid created----------------------
# -----------------726 New grid created----------------------
# -----------------727 New grid created----------------------
# -----------------728 New grid created----------------------
# -----------------729 New grid created----------------------
# -----------------730 New grid created----------------------
# -----------------731 New grid created----------------------
# -----------------732 New grid created----------------------
# -----------------733 New grid created----------------------
# -----------------734 New grid created----------------------
# -----------------735 New grid created----------------------
# -----------------736 New grid created----------------------
# -----------------737 New grid created----------------------
# -----------------738 New grid created----------------------
# -----------------739 New grid created----------------------
# -----------------740 New grid created----------------------
# -----------------741 New grid created----------------------
# -----------------742 New grid created----------------------
# -----------------743 New grid created----------------------
# -----------------744 New grid created----------------------
# -----------------745 New grid created----------------------
# -----------------746 New grid created----------------------
# -----------------747 New grid created----------------------
# -----------------748 New grid created----------------------
# -----------------749 New grid created----------------------
# -----------------750 New grid created----------------------
# -----------------751 New grid created----------------------
# -----------------752 New grid created----------------------
# -----------------753 New grid created----------------------
# -----------------754 New grid created----------------------
# -----------------755 New grid created----------------------
# -----------------756 New grid created----------------------
# -----------------757 New grid created----------------------
# -----------------758 New grid created----------------------
# -----------------759 New grid created----------------------
# -----------------760 New grid created----------------------
# -----------------761 New grid created----------------------
# -----------------762 New grid created----------------------
# -----------------763 New grid created----------------------
# -----------------764 New grid created----------------------
# -----------------765 New grid created----------------------
# -----------------766 New grid created----------------------
# -----------------767 New grid created----------------------
# -----------------768 New grid created----------------------
# -----------------769 New grid created----------------------
# -----------------770 New grid created----------------------
# -----------------771 New grid created----------------------
# -----------------772 New grid created----------------------
# -----------------773 New grid created----------------------
# -----------------774 New grid created----------------------
# -----------------775 New grid created----------------------
# -----------------776 New grid created----------------------
# -----------------777 New grid created----------------------
# -----------------778 New grid created----------------------
# -----------------779 New grid created----------------------
# -----------------780 New grid created----------------------
# -----------------781 New grid created----------------------
# -----------------782 New grid created----------------------
# -----------------783 New grid created----------------------
# -----------------784 New grid created----------------------
# -----------------785 New grid created----------------------
# -----------------786 New grid created----------------------
# -----------------787 New grid created----------------------
# -----------------788 New grid created----------------------
# -----------------789 New grid created----------------------
# -----------------790 New grid created----------------------
# -----------------791 New grid created----------------------
# -----------------792 New grid created----------------------
# -----------------793 New grid created----------------------
# -----------------794 New grid created----------------------
# -----------------795 New grid created----------------------
# -----------------796 New grid created----------------------
# -----------------797 New grid created----------------------
# -----------------798 New grid created----------------------
# -----------------799 New grid created----------------------
# -----------------800 New grid created----------------------
# ...
# -----------------42009 New grid created----------------------
# -----------------42010 New grid created----------------------
# -----------------42011 New grid created----------------------
# -----------------42012 New grid created----------------------
# -----------------42013 New grid created----------------------
# -----------------42014 New grid created----------------------
# -----------------42015 New grid created----------------------
# -----------------42016 New grid created----------------------
# -----------------42017 New grid created----------------------
# -----------------42018 New grid created----------------------
# -----------------42019 New grid created----------------------
# -----------------42020 New grid created----------------------
# -----------------42021 New grid created----------------------
# -----------------42022 New grid created----------------------
# -----------------42023 New grid created----------------------
# -----------------42024 New grid created----------------------
# -----------------42025 New grid created----------------------
# -----------------42026 New grid created----------------------
# -----------------42027 New grid created----------------------
# -----------------42028 New grid created----------------------
# -----------------42029 New grid created----------------------
# -----------------42030 New grid created----------------------
# -----------------42031 New grid created----------------------
# -----------------42032 New grid created----------------------
# -----------------42033 New grid created----------------------
# -----------------42034 New grid created----------------------
# -----------------42035 New grid created----------------------
# -----------------42036 New grid created----------------------
# -----------------42037 New grid created----------------------
# -----------------42038 New grid created----------------------
# -----------------42039 New grid created----------------------
# -----------------42040 New grid created----------------------
# -----------------42041 New grid created----------------------
# -----------------42042 New grid created----------------------
# -----------------42043 New grid created----------------------
# -----------------42044 New grid created----------------------
# -----------------42045 New grid created----------------------
# -----------------42046 New grid created----------------------
# -----------------42047 New grid created----------------------
# -----------------42048 New grid created----------------------
# -----------------42049 New grid created----------------------
# -----------------42050 New grid created----------------------
# -----------------42051 New grid created----------------------
# -----------------42052 New grid created----------------------
# -----------------42053 New grid created----------------------
# -----------------42054 New grid created----------------------
# -----------------42055 New grid created----------------------
# -----------------42056 New grid created----------------------
# -----------------42057 New grid created----------------------
# -----------------42058 New grid created----------------------
# -----------------42059 New grid created----------------------
# -----------------42060 New grid created----------------------
# -----------------42061 New grid created----------------------
# -----------------42062 New grid created----------------------
# -----------------42063 New grid created----------------------
# -----------------42064 New grid created----------------------
# -----------------42065 New grid created----------------------
# -----------------42066 New grid created----------------------
# -----------------42067 New grid created----------------------
# -----------------42068 New grid created----------------------
# -----------------42069 New grid created----------------------
# -----------------42070 New grid created----------------------
# -----------------42071 New grid created----------------------
# -----------------42072 New grid created----------------------
# -----------------42073 New grid created----------------------
# -----------------42074 New grid created----------------------
# -----------------42075 New grid created----------------------
# -----------------42076 New grid created----------------------
# -----------------42077 New grid created----------------------
# -----------------42078 New grid created----------------------
# -----------------42079 New grid created----------------------
# -----------------42080 New grid created----------------------
# -----------------42081 New grid created----------------------
# -----------------42082 New grid created----------------------
# -----------------42083 New grid created----------------------
# -----------------42084 New grid created----------------------
# -----------------42085 New grid created----------------------
# -----------------42086 New grid created----------------------
# -----------------42087 New grid created----------------------
# -----------------42088 New grid created----------------------
# -----------------42089 New grid created----------------------
# -----------------42090 New grid created----------------------
# -----------------42091 New grid created----------------------
# -----------------42092 New grid created----------------------
# -----------------42093 New grid created----------------------
# -----------------42094 New grid created----------------------
# -----------------42095 New grid created----------------------
# -----------------42096 New grid created----------------------
# -----------------42097 New grid created----------------------
# -----------------42098 New grid created----------------------
# -----------------42099 New grid created----------------------
# -----------------42100 New grid created----------------------
# -----------------42101 New grid created----------------------
# -----------------42102 New grid created----------------------
# -----------------42103 New grid created----------------------
# -----------------42104 New grid created----------------------
# -----------------42105 New grid created----------------------
# -----------------42106 New grid created----------------------
# -----------------42107 New grid created----------------------
# -----------------42108 New grid created----------------------
# -----------------42109 New grid created----------------------
# -----------------42110 New grid created----------------------
# -----------------42111 New grid created----------------------
# -----------------42112 New grid created----------------------
# -----------------42113 New grid created----------------------
# -----------------42114 New grid created----------------------
# -----------------42115 New grid created----------------------
# -----------------42116 New grid created----------------------
# -----------------42117 New grid created----------------------
# -----------------42118 New grid created----------------------
# -----------------42119 New grid created----------------------
# -----------------42120 New grid created----------------------
# -----------------42121 New grid created----------------------
# -----------------42122 New grid created----------------------
# -----------------42123 New grid created----------------------
# -----------------42124 New grid created----------------------
# -----------------42125 New grid created----------------------
# -----------------42126 New grid created----------------------
# -----------------42127 New grid created----------------------
# -----------------42128 New grid created----------------------
# -----------------42129 New grid created----------------------
# -----------------42130 New grid created----------------------
# -----------------42131 New grid created----------------------
# -----------------42132 New grid created----------------------
# -----------------42133 New grid created----------------------
# -----------------42134 New grid created----------------------
# -----------------42135 New grid created----------------------
# -----------------42136 New grid created----------------------
# -----------------42137 New grid created----------------------
# -----------------42138 New grid created----------------------
# -----------------42139 New grid created----------------------
# -----------------42140 New grid created----------------------
# -----------------42141 New grid created----------------------
# -----------------42142 New grid created----------------------
# -----------------42143 New grid created----------------------
# -----------------42144 New grid created----------------------
# -----------------42145 New grid created----------------------
# -----------------42146 New grid created----------------------
# -----------------42147 New grid created----------------------
# -----------------42148 New grid created----------------------
# -----------------42149 New grid created----------------------
# -----------------42150 New grid created----------------------
# -----------------42151 New grid created----------------------
# -----------------42152 New grid created----------------------
# -----------------42153 New grid created----------------------
# -----------------42154 New grid created----------------------
# -----------------42155 New grid created----------------------
# -----------------42156 New grid created----------------------
# -----------------42157 New grid created----------------------
# -----------------42158 New grid created----------------------
# -----------------42159 New grid created----------------------
# -----------------42160 New grid created----------------------
# -----------------42161 New grid created----------------------
# -----------------42162 New grid created----------------------
# -----------------42163 New grid created----------------------
# -----------------42164 New grid created----------------------
# -----------------42165 New grid created----------------------
# -----------------42166 New grid created----------------------
# -----------------42167 New grid created----------------------
# -----------------42168 New grid created----------------------
# -----------------42169 New grid created----------------------
# -----------------42170 New grid created----------------------
# -----------------42171 New grid created----------------------
# -----------------42172 New grid created----------------------
# -----------------42173 New grid created----------------------
# -----------------42174 New grid created----------------------
# -----------------42175 New grid created----------------------
# -----------------42176 New grid created----------------------
# -----------------42177 New grid created----------------------
# -----------------42178 New grid created----------------------
# -----------------42179 New grid created----------------------
# -----------------42180 New grid created----------------------
# -----------------42181 New grid created----------------------
# -----------------42182 New grid created----------------------
# -----------------42183 New grid created----------------------
# -----------------42184 New grid created----------------------
# -----------------42185 New grid created----------------------
# -----------------42186 New grid created----------------------
# -----------------42187 New grid created----------------------
# -----------------42188 New grid created----------------------
# -----------------42189 New grid created----------------------
# -----------------42190 New grid created----------------------
# -----------------42191 New grid created----------------------
# -----------------42192 New grid created----------------------
# -----------------42193 New grid created----------------------
# -----------------42194 New grid created----------------------
# -----------------42195 New grid created----------------------
# -----------------42196 New grid created----------------------
# -----------------42197 New grid created----------------------
# -----------------42198 New grid created----------------------
# -----------------42199 New grid created----------------------
# -----------------42200 New grid created----------------------
# -----------------42201 New grid created----------------------
# -----------------42202 New grid created----------------------
# -----------------42203 New grid created----------------------
# -----------------42204 New grid created----------------------
# -----------------42205 New grid created----------------------
# -----------------42206 New grid created----------------------
# -----------------42207 New grid created----------------------
# -----------------42208 New grid created----------------------
# -----------------42209 New grid created----------------------
# -----------------42210 New grid created----------------------
# -----------------42211 New grid created----------------------
# -----------------42212 New grid created----------------------
# -----------------42213 New grid created----------------------
# -----------------42214 New grid created----------------------
# -----------------42215 New grid created----------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# z:\users\Jiyong\Simulation\Coursework\Advanced quantum mechanics\phys765_advanced_quantum\project1\problem2\worm_simulation.ipynb Cell 12 in <cell line: 48>()
#      <a href='vscode-notebook-cell:/z%3A/users/Jiyong/Simulation/Coursework/Advanced%20quantum%20mechanics/phys765_advanced_quantum/project1/problem2/worm_simulation.ipynb#X14sZmlsZQ%3D%3D?line=51'>52</a>     es.append(e_tilda)
#      <a href='vscode-notebook-cell:/z%3A/users/Jiyong/Simulation/Coursework/Advanced%20quantum%20mechanics/phys765_advanced_quantum/project1/problem2/worm_simulation.ipynb#X14sZmlsZQ%3D%3D?line=52'>53</a>     grid = update_grid(grid)
# ---> <a href='vscode-notebook-cell:/z%3A/users/Jiyong/Simulation/Coursework/Advanced%20quantum%20mechanics/phys765_advanced_quantum/project1/problem2/worm_simulation.ipynb#X14sZmlsZQ%3D%3D?line=54'>55</a>     print('-----------------' + str(counter) + ' New grid created----------------------')
#      <a href='vscode-notebook-cell:/z%3A/users/Jiyong/Simulation/Coursework/Advanced%20quantum%20mechanics/phys765_advanced_quantum/project1/problem2/worm_simulation.ipynb#X14sZmlsZQ%3D%3D?line=56'>57</a> Monte_Carlo_try = range(num_trials)
#      <a href='vscode-notebook-cell:/z%3A/users/Jiyong/Simulation/Coursework/Advanced%20quantum%20mechanics/phys765_advanced_quantum/project1/problem2/worm_simulation.ipynb#X14sZmlsZQ%3D%3D?line=57'>58</a> _plt.rcParams['figure.facecolor'] = 'white'
#
# File c:\Users\jiyon\anaconda3\lib\site-packages\ipykernel\iostream.py:531, in OutStream.write(self, string)
#     529 is_child = (not self._is_master_process())
#     530 # only touch the buffer in the IO thread to avoid races
# --> 531 self.pub_thread.schedule(lambda: self._buffer.write(string))
#     532 if is_child:
#     533     # mp.Pool cannot be trusted to flush promptly (or ever),
#     534     # and this helps.
#     535     if self._subprocess_flush_pending:
#
# File c:\Users\jiyon\anaconda3\lib\site-packages\ipykernel\iostream.py:216, in IOPubThread.schedule(self, f)
#     214     self._events.append(f)
#     215     # wake event thread (message content is ignored)
# --> 216     self._event_pipe.send(b'')
#     217 else:
#     218     f()
#
# File c:\Users\jiyon\anaconda3\lib\site-packages\zmq\sugar\socket.py:547, in Socket.send(self, data, flags, copy, track, routing_id, group)
#     540         data = zmq.Frame(
#     541             data,
#     542             track=track,
#     543             copy=copy or None,
#     544             copy_threshold=self.copy_threshold,
#     545         )
#     546     data.group = group
# --> 547 return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#
# File zmq\backend\cython\socket.pyx:718, in zmq.backend.cython.socket.Socket.send()
#
# File zmq\backend\cython\socket.pyx:765, in zmq.backend.cython.socket.Socket.send()
#
# File zmq\backend\cython\socket.pyx:242, in zmq.backend.cython.socket._send_copy()
#
# File c:\Users\jiyon\anaconda3\lib\site-packages\zmq\backend\cython\checkrc.pxd:13, in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %% [markdown]
# # Now do analysis, plot results, etc

# %%
test1 = _np.array([1,2,3])
test2 = _np.array([2,3,4])
test1==test2
_np.all(test1==test2)
# Out:
# False

# %% [markdown]
# ## Scratch Work

# %%
a = [1, 2, 3, 4]

a[2:]
# Out:
# [3, 4]
